# %%
import pandas as pd
import numpy as np

# %%
df_oscar = pd.read_csv('datasets/oscarwinners.csv')
df_novo_padronizado = pd.read_csv('datasets/oscar_vencedores_2014_2024_organizado.csv')

# %% [markdown]
# Unir os dois datasets

# %%
df_final = pd.concat([df_oscar, df_novo_padronizado], ignore_index=True)
print(f"Total de linhas na base unificada: {len(df_oscar)}")
print(f"Total de linhas na base após união: {len(df_final)}")
df_final.head()
# Out:
# Total de linhas na base unificada: 415
# Total de linhas na base após união: 465
#                name  birth_year  birth_date                birthplace  \
# 0    Marie Dressler      1868.0  1868-11-02  Cobourg, Ontario, Canada
# 1     George Arliss      1868.0  1868-04-10           London, England
# 2      Edmund Gwenn      1875.0  1875-09-26  Vale of Glamorgan, Wales
# 3    Charles Coburn      1877.0  1877-06-17              Savannah, Ga
# 4  Lionel Barrymore      1878.0  1878-04-28          Philadelphia, Pa
#
#   race_ethnicity        religion sexual_orientation  year_edition  \
# 0          White             NaN           Straight        1931.0
# 1          White             NaN           Straight        1930.0
# 2          White             NaN                 Na        1948.0
# 3          White             NaN           Straight        1944.0
# 4          White  Roman Catholic           Straight        1931.0
#
#                 category                   movie
# ...
